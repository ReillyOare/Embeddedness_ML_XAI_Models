# %% [markdown]
# # VADEQ & StreamStats Model Evaluation
#
# The purpose of this Jupyter notebook is to evaluate the selected model (XGBoost) for the VADEQ and StreamStats dataset. This will evaluate model accuracy, XAI, and geographic visualizations.
#
# Emma Reilly Oare

# %%
#Read in libs
import pandas as pd
import numpy as np
import pylab
import math
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.graph_objects as go

import scipy.stats as stats
import keras_tuner as kt
import keras
from scipy.optimize import curve_fit
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler, RobustScaler, OneHotEncoder, PowerTransformer, QuantileTransformer
from sklearn.model_selection import train_test_split, RandomizedSearchCV, KFold, cross_val_score, GridSearchCV, RepeatedKFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, mean_absolute_error
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
import statsmodels.api as sm
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import openpyxl
from scikeras.wrappers import KerasClassifier, KerasRegressor
from keras.models import Sequential 
from keras.layers import Dense, BatchNormalization, Dropout, Input
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam   
from keras import regularizers  
from keras_tuner import RandomSearch
from scipy.stats import uniform, expon
import plotly.express as px
import plotly.graph_objects as go
from ipywidgets import widgets, interact
import os
import warnings
from dbfread import DBF
from xgboost import XGBRegressor
import joblib
import shap
import textwrap
from sklearn.inspection import permutation_importance, PartialDependenceDisplay

# %% [markdown]
# ## Step 1. Import dataset

# %%
# Define base directory
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "../../.."))

# %%
# Define paths
train_test_path = os.path.join(BASE_DIR, "data", "model_ready", "train_test_sets.pkl")
mdl_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "trained_xgboost_model.pkl")

# Load train-test sets and model
x_train, x_test, y_train, y_test = joblib.load(train_test_path)
xgb_model = joblib.load(mdl_path)

# %% [markdown]
# ## Step 2: Present metrics

# %%
# Read in metric dataframe
metric_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "vadeq_strmsts_models_metrics.xlsx")
metric_df = pd.read_excel(metric_path)

# %%
# Display metrics for selected model
metric_df.iloc[3,:]
# Out:
# Unnamed: 0            3
# Model           XGBoost
# CV RMSE       13.837825
# CV MAE        10.946327
# CV R2            0.6277
# Name: 3, dtype: object

# %% [markdown]
# ## Step 3. Model Evaluation

# %% [markdown]
# ### Step 3a. Model Predictions vs. True

# %%
# Create predictions
xgb_pred = xgb_model.predict(x_test)
# Reshape y_test to numpy array for residual calculations
y_test_np = y_test.to_numpy().reshape(y_test.shape[0])

# Calculate_residuals
xgb_residuals = y_test_np - xgb_pred

# Display residual shape
xgb_residuals.shape
# Out:
# (224,)

# %%
# Print residual statistics
print("The maximum residual is", round(np.abs(xgb_residuals).max(), 4), "% embeddedness.")
print("The median residual is", round(np.median(np.abs(xgb_residuals)), 4), "% embeddedness.")
print("The minimum residual is", round(np.abs(xgb_residuals).min(), 4), "% embeddedness.")
# Out:
# The maximum residual is 30.4632 % embeddedness.
# The median residual is 4.4849 % embeddedness.
# The minimum residual is 0.021 % embeddedness.

# %%
# Plot predictions vs true
plt.scatter(y_test, # true vals
            xgb_pred, # predictions
            color = 'maroon',
            s = 25,
            edgecolors = 'black',
            linewidths = 0.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('XGBoost Predictions vs. True')
plt.ylim([0, 100])
plt.xlim([0, 100])
plt.plot([0, 100], [0, 100], # plot perfect fit
         color = 'k',
         linestyle = '--',
         linewidth = 0.75)

# Save to results folder
predict_true_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "xgb_predict_vs_true.png")
plt.savefig(predict_true_path, dpi = 300)

# Show plot
plt.show()

# %% [markdown]
# ### Step 3b. Residual scatter plot

# %%
# Plot residuals
plt.scatter(xgb_pred, # predictions
            xgb_residuals, # corresponding residuals
            color = 'maroon',
            s = 25,
            edgecolors = 'black',
            linewidths = 0.5)
plt.xlabel('Predicted Embeddedness Values (%)')
plt.ylabel('Residuals')
plt.title('XGBoost Residual Plot')
plt.ylim([-100, 100])
plt.xlim([0, 100])

# Plot perfect prediction line
plt.axhline(y = 0,
            color = 'k',
            linestyle = '--',
           linewidth = 0.75)

# Plot boundaries
plt.plot([100, 0], [0, 100],
         color = 'k',
         linestyle = ':',
         linewidth = 0.75)
plt.plot([100, 0], [-100, 0],
         color = 'k',
         linestyle = ':',
         linewidth = 0.75)

# Save to results folder
resid_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "xgb_residuals.png")
plt.savefig(resid_path, dpi = 300)

# Show plot
plt.show()

# %% [markdown]
# ### Step 3c. Plot residual histogram
# We want to ensure we are having normally distributed residuals from the model.

# %%
# Plot residuals distribution to check for Gaussian distribution
plt.figure(figsize=(10, 6))
sns.histplot(xgb_residuals, kde=True, color = 'maroon')
plt.xlabel('Residuals (%)')
plt.title('Distribution of Residuals for XGBoost')

# Save to results folder
resid_hist_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "xgb_residual_hist.png")
plt.savefig(resid_hist_path, dpi = 300)

# Show plot
plt.show()

# %% [markdown]
# ## Step 4. Explainability

# %% [markdown]
# ### Step 4a. Feature Importance

# %% [markdown]
# We are going to plot three different feature importances:
# 1. **Weight:** The percentage representing the relative number of times a particular feature occurs in the trees (ex. if feature1 occurred in 2 splits, 1 split and 3 splits in each of tree1, tree2 and tree3; then the weight for feature1 will be 2+1+3 = 6)
# 2. **Gain:** The improvement in accuracy brought by a feature to the branches it is on. The idea is that before adding a new split on a feature X to the branch there was some wrongly classified elements, after adding the split on this feature, there are two new branches, and each of these branch is more accurate.
# 3. **Cover:** The relative number of observations related to a feature (ex. if you have 100 observations, 4 features and 3 trees, and suppose feature1 is used to decide the leaf node for 10, 5, and 2 observations in tree1, tree2 and tree3 respectively; then the metric will count cover for this feature as 10+5+2 = 17)
# <br><br> The above definitions are found directly from https://medium.com/towards-data-science/be-careful-when-interpreting-your-features-importance-in-xgboost-6e16132588e7

# %%
# Define the importance types
importance_types = ['weight', 'gain', 'cover']

# Initialize a dictionary to hold importances
importances = {}

# Extract importances for each type
for importance_type in importance_types:
    importances[importance_type] = xgb_model.get_booster().get_score(importance_type=importance_type)
importance_df = pd.DataFrame(importances)

# %%
# Display importance dateframe
importance_df
# Out:
#                                                     weight         gain  \
# Area-weighted average soil depth (QT)               2793.0  1728.180420
# Mean Basin Elevation (QT)                           2992.0  1267.421997
# % of Soils with greater than 10% and less than ...  1051.0   536.600830
# Relief (QT)                                         2428.0   565.782410
# Area-weighted Average Soil Permeability (log)       1420.0   463.363678
# % of Soils with greater than 40% and less than ...   388.0   461.881012
# % of Forests and Shrub Lands (NLCD 2011) (YJ)       1897.0   875.794189
# % of Cultivated Crop and Pasture (NLCD 2011) (s...  1626.0   537.376526
# Max 24-Hour Precipitation for 2-Year Return Per...  1835.0   638.983459
# Mean Annual Precipitation (QT)                      1750.0   515.201416
# Year                                                2029.0   320.833435
# Drainage Area (sq km) (QT)                          1493.0   446.551819
# Peak Flow Region Number 1550                          21.0  2379.523682
# Peak Flow Region Number 1551                         129.0  1671.467163
# Peak Flow Region Number 1552                         106.0  1300.219238
# Peak Flow Region Number 1553                         132.0  1101.674072
# Peak Flow Region Number 1554                         117.0  2361.381836
# Peak Flow Region Number 1555                          46.0   624.475525
#
#                                                          cover
# Area-weighted average soil depth (QT)                82.369492
# Mean Basin Elevation (QT)                            71.765373
# % of Soils with greater than 10% and less than ...   56.052330
# Relief (QT)                                          58.553543
# Area-weighted Average Soil Permeability (log)        51.119015
# % of Soils with greater than 40% and less than ...   62.752579
# % of Forests and Shrub Lands (NLCD 2011) (YJ)        79.465996
# % of Cultivated Crop and Pasture (NLCD 2011) (s...   62.145142
# Max 24-Hour Precipitation for 2-Year Return Per...   65.476837
# Mean Annual Precipitation (QT)                       60.901714
# Year                                                 40.558895
# Drainage Area (sq km) (QT)                           55.028801
# Peak Flow Region Number 1550                        115.857140
# Peak Flow Region Number 1551                        191.255814
# Peak Flow Region Number 1552                        172.641510
# Peak Flow Region Number 1553                         83.340912
# Peak Flow Region Number 1554                        203.820511
# Peak Flow Region Number 1555                         76.630432

# %%
# Plot different importance features
num_importance_types = importance_df.columns.size
plt.figure(figsize = (10, 6 * num_importance_types))

for i, importance_type in enumerate(importance_df.columns):
    plt.subplot(num_importance_types, 1, i + 1)
    # Sort the features by importance
    sorted_features = importance_df[importance_type].sort_values(ascending = False).head(20)
    sns.barplot(x=sorted_features.values, y = sorted_features.index, palette='gist_heat', hue = sorted_features.index)
    plt.xlabel(f'Feature {importance_type.capitalize()} Importance')
    plt.ylabel('Features')
    plt.title(f'Feature Importance by {importance_type.capitalize()}')

# Save to results folder
feat_imp_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "xgb_feature_importances.png")
plt.savefig(feat_imp_path, dpi = 300, bbox_inches = 'tight')

# Plot bar plots
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Permutation Importance
# Permutaton importance measures the increase in predicted error of the model after we permuted the feature's values. Permuting is the rearrangement of features. We measure the importance of a feature by calculating the increase in the model's prediction error after shuffling. A feature is “important” if shuffling its values increases the model error, because in this case the model relied on the feature for the prediction.
#
# <br> Explanation from https://christophm.github.io/interpretable-ml-book/feature-importance.html

# %%
# Wrap feature names to a maximum width
x_shap = x_test.copy() # Create duplicate for wrapping
import textwrap
x_shap.columns = [textwrap.fill(name, width = 32.5) for name in x_shap.columns]

# %%
# Compute permutation importance
result = permutation_importance(xgb_model, x_test, y_test)

# Create DataFrame for results
perm_importance_df = pd.DataFrame({'Feature': x_shap.columns.values.tolist(),
                                'Importance': result.importances_mean,
                                'Std': result.importances_std}).sort_values(by='Importance', ascending=True)

# Plot figure
plt.figure(figsize=(10, 8))
plt.barh(perm_importance_df['Feature'], 
         perm_importance_df['Importance'], 
         xerr = perm_importance_df['Std'], 
         color = 'maroon')
plt.xlabel('Decrease in RMSE')
plt.title('Permutation Feature Importance')
plt.tight_layout()

# Save figure to results folder
perm_imp_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "xgb_permutation_importances.png")
plt.savefig(perm_imp_path, dpi = 300, bbox_inches = 'tight')

# Show figure
plt.show()

# %% [markdown]
# ### Step 4b. Global SHAP plots

# %%
import shap

# Initialize the SHAP explainer
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(x_test)

# Wrap feature names to a maximum width
x_shap = x_test.copy() # Create duplicate for wrapping
import textwrap
x_shap.columns = [textwrap.fill(name, width = 32.5) for name in x_shap.columns]

# %% [markdown]
# #### Summary Plot (Bar)
# The summary plot offers a comprehensive view of the most influential features in a model. It **ranks** features based on their effect on the model's predictions. The bar plot specifically presents each feature's average absolute SHAP values.

# %%
# SHAP Summary Plot (Bar)
plt.title("SHAP Feature Importance (Bar Plot)")
shap.summary_plot(shap_values, x_shap, 
                  plot_type = "bar", 
                  show = False,
                  color = 'maroon')
plt.xlabel('SHAP Value')

# Save to results folder
shap_bar_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_summary_bar.png")
plt.savefig(shap_bar_path, dpi = 300, bbox_inches = 'tight')

# Show plot
plt.show()

# %% [markdown]
# #### Summary Plot (Dot)
# The dot summary plot is similar to the bar, but each dot represents a specific prediction. The feature value relates directly to the features actual numerical value, while it's location on the x-axis denotes its effect on the model prediction.

# %%
# SHAP Summary Plot Dot)
plt.title("SHAP Feature Importance (Dot)")
shap.summary_plot(shap_values, x_shap, 
                  show = False)
plt.xlabel('SHAP Value')

# Save to results folder
shap_dot_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_summary_dot.png")
plt.savefig(shap_dot_path, dpi = 300, bbox_inches = 'tight')

# Show plot
plt.show()

# %% [markdown]
# #### Dependence Plots
# We'll look at the top five features and use a dependence plot. These are still global (for the full test set).

# %%
# Shows comparison to soil depth
shap.dependence_plot('Area-weighted average soil depth\n(QT)', 
                     shap_values, 
                     x_shap,
                    interaction_index = None,
                    color = 'maroon',
                    show = False)

# Save to results folder
shap_soil_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_soil_dependence.png")
plt.savefig(shap_soil_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Shows comparison to elevation
shap.dependence_plot('Mean Basin Elevation (QT)', 
                     shap_values, 
                     x_shap,
                    interaction_index = None,
                    color = 'maroon',
                    show = False)

# Save to results folder
shap_elev_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_elev_dependence.png")
plt.savefig(shap_elev_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Shows comparison to forest/shrub
shap.dependence_plot('% of Forests and Shrub Lands\n(NLCD 2011) (YJ)', 
                     shap_values, 
                     x_shap,
                    interaction_index = None,
                    color = 'maroon',
                    show = False)

# Save to results folder
shap_forest_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_forest_dependence.png")
plt.savefig(shap_forest_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Shows comparison to relief
shap.dependence_plot('Relief (QT)', 
                     shap_values, 
                     x_shap,
                    interaction_index = None,
                    color = 'maroon',
                    show = False)

# Save to results folder
shap_relief_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_relief_dependence.png")
plt.savefig(shap_relief_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Shows comparison to 2-yr return period max precip
shap.dependence_plot('Max 24-Hour Precipitation for\n2-Year Return Period (QT)', 
                     shap_values, 
                     x_shap,
                    interaction_index = None,
                    color = 'maroon',
                    show = False)

# Save to results folder
shap_2yrprecip_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_2yrprecip_dependence.png")
plt.savefig(shap_2yrprecip_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %% [markdown]
# ### Step 4c. Local SHAP Plots
# The local SHAP plots are for looking at specific predictions in the test set. We're going to look at:
# - Two maximum positive residuals
# - Two maximum negative residuals
# - Two lowest residuals

# %%
# Create dataframe of predicted, true, and residuals
results_df = pd.DataFrame({'True': y_test_np,
                           'Predicted': xgb_pred,
                           'Residual': xgb_residuals})

# Display dataframe
results_df
# Out:
#           True  Predicted   Residual
# 0    27.636364  40.437912 -12.801548
# 1    29.454545  26.733158   2.721387
# 2    31.203704  30.756920   0.446784
# 3    90.000000  82.792809   7.207191
# 4    80.545455  77.352081   3.193373
# ..         ...        ...        ...
# 219  65.454545  62.344250   3.110296
# 220  73.090909  69.660927   3.429982
# 221  92.181818  87.479332   4.702486
# 222  46.078431  49.421711  -3.343280
# 223  27.363636  57.826794 -30.463157
#
# [224 rows x 3 columns]

# %%
# Sort to find key cases
max_positive_residual = results_df.nlargest(2, 'Residual')
max_negative_residual = results_df.nsmallest(2, 'Residual')
lowest_residuals = results_df.iloc[(results_df['Residual'] - 0).abs().argsort()[:2]]  # Most accurate predictions

# Combine all selected instances
selected_instances = pd.concat([max_positive_residual, max_negative_residual, lowest_residuals])

# Print results
selected_instances
# Out:
#           True  Predicted   Residual
# 41   60.727273  36.299614  24.427659
# 201  93.454545  73.587852  19.866693
# 223  27.363636  57.826794 -30.463157
# 100  17.818182  39.690002 -21.871821
# 149  87.636364  87.657387  -0.021023
# 7    48.727273  48.840046  -0.112773

# %% [markdown]
# #### Force Plots
# The SHAP force plots explain the deviation from an expected value by showing how each feature pushes the prediction up or down. The *expected_value* is the average model prediction. The *f(x)* is the final predicted value for the given instance.

# %%
# Define index being used
index = selected_instances.iloc[0].name
# Initialize javascript lib
shap.initjs()

# Plot force plot
shap.plots.force(explainer.expected_value, 
                 shap_values[index], 
                 x_shap.iloc[index],
                text_rotation = 90)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iPJY1961Q7FDNP1F87I7G'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 59.63934326171875, "outValue": 36.29962921142578, "link": "identity", "featureNames": ["Area-weighted average soil depth\n(QT)", "Mean Basin Elevation (QT)", "% of Soils with greater than 10%\nand less than 20% Clay (sqrt)", "Relief (QT)", "Area-weighted Average Soil\nPermeability (log)", "% of Soils with greater than 40%\nand less than 50% Clay (cbrt)", "% of Forests and Shrub Lands\n(NLCD 2011) (YJ)", "% of Cultivated Crop and Pasture\n(NLCD 2011) (sqrt)", "Max 24-Hour Precipitation for\n2-Year Return Period (QT)", "Mean Annual Precipitation (QT)", "Year", "Drainage Area (sq km) (QT)", "Peak Flow Region Number 1550", "Peak Flow Region Number 1551", "Peak Flow Region Number 1552", "Peak Flow Region Number 1553", "Peak Flow Region Number 1554", "Peak Flow Region Number 1555"], "features": {"0": {"effect": -9.46638298034668, "value": -1.288117584458971}, "1": {"effect": -5.564486503601074, "value": 0.3758460048124753}, "2": {"effect": -0.8192064166069031, "value": 1.3205995826747505}, "3": {"effect": -1.326548457145691, "value": 0.44549571152369427}, "4": {"effect": -0.7270733714103699, "value": 1.3957183157055502}, "5": {"effect": -0.11654102057218552, "value": 0.0}, "6": {"effect": -4.354793548583984, "value": 0.914648852607849}, "7": {"effect": 0.11713801324367523, "value": -0.5449429245763112}, "8": {"effect": -0.25146570801734924, "value": -0.06190133219500105}, "9": {"effect": -0.5282213091850281, "value": -0.498317116824571}, "10": {"effect": 1.1738044023513794, "value": 0.3}, "11": {"effect": 0.11748755723237991, "value": -0.6012715530006651}, "12": {"effect": -0.0738513320684433, "value": 0.0}, "13": {"effect": -0.2979724109172821, "value": 0.0}, "14": {"effect": 0.08865366876125336, "value": 0.0}, "15": {"effect": -0.07081732153892517, "value": 0.0}, "16": {"effect": -1.2022088766098022, "value": 1.0}, "17": {"effect": -0.037227943539619446, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iPJY1961Q7FDNP1F87I7G')
#   );
# </script>

# %%
# Print information on sample above
print(f"Force Plot for instance where True Value = {(selected_instances.iloc[0, 0]):.2f}, Predicted Value = {selected_instances.iloc[0, 1]:.2f}, and Residual = {selected_instances.iloc[0, 2]:.2f}")
# Out:
# Force Plot for instance where True Value = 60.73, Predicted Value = 36.30, and Residual = 24.43

# %%
# Define index being used
index = selected_instances.iloc[1].name

# Plot force plot
shap.plots.force(explainer.expected_value, 
                 shap_values[index], 
                 x_shap.iloc[index],
                text_rotation = 90)
# Out:
# <div id='iOEYGK51ZZGX3EXGW4CT2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 59.63934326171875, "outValue": 73.58786010742188, "link": "identity", "featureNames": ["Area-weighted average soil depth\n(QT)", "Mean Basin Elevation (QT)", "% of Soils with greater than 10%\nand less than 20% Clay (sqrt)", "Relief (QT)", "Area-weighted Average Soil\nPermeability (log)", "% of Soils with greater than 40%\nand less than 50% Clay (cbrt)", "% of Forests and Shrub Lands\n(NLCD 2011) (YJ)", "% of Cultivated Crop and Pasture\n(NLCD 2011) (sqrt)", "Max 24-Hour Precipitation for\n2-Year Return Period (QT)", "Mean Annual Precipitation (QT)", "Year", "Drainage Area (sq km) (QT)", "Peak Flow Region Number 1550", "Peak Flow Region Number 1551", "Peak Flow Region Number 1552", "Peak Flow Region Number 1553", "Peak Flow Region Number 1554", "Peak Flow Region Number 1555"], "features": {"0": {"effect": 0.4053068459033966, "value": -0.4432134186963743}, "1": {"effect": -2.2662277221679688, "value": 0.6368990635906666}, "2": {"effect": 3.379582643508911, "value": 1.258940818566523}, "3": {"effect": -0.03157825022935867, "value": 0.46441718033285384}, "4": {"effect": 2.9678378105163574, "value": 0.4579190247663999}, "5": {"effect": -0.1687350571155548, "value": 0.0}, "6": {"effect": 4.111019134521484, "value": 0.39353898281785105}, "7": {"effect": -0.20613232254981995, "value": -1.033297860197654}, "8": {"effect": -0.8402761816978455, "value": -0.5543885749133846}, "9": {"effect": 2.94521427154541, "value": 1.5696933403676139}, "10": {"effect": 1.5615335702896118, "value": 0.0}, "11": {"effect": 0.624640703201294, "value": 0.09929921763604893}, "12": {"effect": -0.026680905371904373, "value": 0.0}, "13": {"effect": -0.5149378776550293, "value": 0.0}, "14": {"effect": 0.13633103668689728, "value": 0.0}, "15": {"effect": 0.08984649926424026, "value": 0.0}, "16": {"effect": 0.716626763343811, "value": 0.0}, "17": {"effect": 1.0651413202285767, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOEYGK51ZZGX3EXGW4CT2')
#   );
# </script>

# %%
# Print information on sample above
print(f"Force Plot for instance where True Value = {(selected_instances.iloc[1, 0]):.2f}, Predicted Value = {selected_instances.iloc[1, 1]:.2f}, and Residual = {selected_instances.iloc[1, 2]:.2f}")
# Out:
# Force Plot for instance where True Value = 93.45, Predicted Value = 73.59, and Residual = 19.87

# %%
# Define index being used
index = selected_instances.iloc[2].name

# Plot force plot
shap.plots.force(explainer.expected_value, 
                 shap_values[index], 
                 x_shap.iloc[index],
                text_rotation = 90)
# Out:
# <div id='iAD93J1TLZUSXDQG2YGR2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 59.63934326171875, "outValue": 57.826805114746094, "link": "identity", "featureNames": ["Area-weighted average soil depth\n(QT)", "Mean Basin Elevation (QT)", "% of Soils with greater than 10%\nand less than 20% Clay (sqrt)", "Relief (QT)", "Area-weighted Average Soil\nPermeability (log)", "% of Soils with greater than 40%\nand less than 50% Clay (cbrt)", "% of Forests and Shrub Lands\n(NLCD 2011) (YJ)", "% of Cultivated Crop and Pasture\n(NLCD 2011) (sqrt)", "Max 24-Hour Precipitation for\n2-Year Return Period (QT)", "Mean Annual Precipitation (QT)", "Year", "Drainage Area (sq km) (QT)", "Peak Flow Region Number 1550", "Peak Flow Region Number 1551", "Peak Flow Region Number 1552", "Peak Flow Region Number 1553", "Peak Flow Region Number 1554", "Peak Flow Region Number 1555"], "features": {"0": {"effect": -0.9639407396316528, "value": 0.21063110925091633}, "1": {"effect": -0.48187193274497986, "value": -0.4729475192986945}, "2": {"effect": 0.472096711397171, "value": 0.0}, "3": {"effect": 1.0824940204620361, "value": -1.0369449324473647}, "4": {"effect": -0.8444804549217224, "value": -0.7206308949182689}, "5": {"effect": -0.2771996259689331, "value": 1.5683933814683806}, "6": {"effect": 0.5920613408088684, "value": 0.29225446841121827}, "7": {"effect": -0.21565066277980804, "value": -0.15671198252679255}, "8": {"effect": 0.43028515577316284, "value": 0.0}, "9": {"effect": -0.4528844356536865, "value": -0.044099416132558265}, "10": {"effect": 0.5296158194541931, "value": -0.8}, "11": {"effect": -2.3665220737457275, "value": -0.6669690413268193}, "12": {"effect": -0.020208757370710373, "value": 0.0}, "13": {"effect": 0.06641599535942078, "value": 1.0}, "14": {"effect": 0.1526256948709488, "value": 0.0}, "15": {"effect": 0.03761536255478859, "value": 0.0}, "16": {"effect": 0.46627333760261536, "value": 0.0}, "17": {"effect": -0.019263120368123055, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iAD93J1TLZUSXDQG2YGR2')
#   );
# </script>

# %%
# Print information on sample above
print(f"Force Plot for instance where True Value = {(selected_instances.iloc[2, 0]):.2f}, Predicted Value = {selected_instances.iloc[2, 1]:.2f}, and Residual = {selected_instances.iloc[2, 2]:.2f}")
# Out:
# Force Plot for instance where True Value = 27.36, Predicted Value = 57.83, and Residual = -30.46

# %%
# Define index being used
index = selected_instances.iloc[3].name

# Plot force plot
shap.plots.force(explainer.expected_value, 
                 shap_values[index], 
                 x_shap.iloc[index],
                text_rotation = 90)
# Out:
# <div id='iPJFYSP69A6WTARRMR3HU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 59.63934326171875, "outValue": 39.69003677368164, "link": "identity", "featureNames": ["Area-weighted average soil depth\n(QT)", "Mean Basin Elevation (QT)", "% of Soils with greater than 10%\nand less than 20% Clay (sqrt)", "Relief (QT)", "Area-weighted Average Soil\nPermeability (log)", "% of Soils with greater than 40%\nand less than 50% Clay (cbrt)", "% of Forests and Shrub Lands\n(NLCD 2011) (YJ)", "% of Cultivated Crop and Pasture\n(NLCD 2011) (sqrt)", "Max 24-Hour Precipitation for\n2-Year Return Period (QT)", "Mean Annual Precipitation (QT)", "Year", "Drainage Area (sq km) (QT)", "Peak Flow Region Number 1550", "Peak Flow Region Number 1551", "Peak Flow Region Number 1552", "Peak Flow Region Number 1553", "Peak Flow Region Number 1554", "Peak Flow Region Number 1555"], "features": {"0": {"effect": -6.3368730545043945, "value": -0.4790097375757692}, "1": {"effect": -5.918225288391113, "value": 0.5280704202853328}, "2": {"effect": -2.518691062927246, "value": 1.2921646841560555}, "3": {"effect": -2.6031241416931152, "value": 0.23725891585045408}, "4": {"effect": -0.8174045085906982, "value": 0.4295117463201637}, "5": {"effect": -0.19461946189403534, "value": 0.0}, "6": {"effect": 0.8609037399291992, "value": 0.5468444661484206}, "7": {"effect": -0.8461640477180481, "value": -0.3915448364047505}, "8": {"effect": -0.7625255584716797, "value": -1.0592492695610642}, "9": {"effect": 0.36773908138275146, "value": 0.5643209661651158}, "10": {"effect": -0.2779060900211334, "value": -0.1}, "11": {"effect": -0.9241935014724731, "value": 0.1349578287973194}, "12": {"effect": -0.06517619639635086, "value": 0.0}, "13": {"effect": -0.5238747000694275, "value": 0.0}, "14": {"effect": 0.1321631371974945, "value": 0.0}, "15": {"effect": 0.0011326108360663056, "value": 0.0}, "16": {"effect": 0.4472091495990753, "value": 0.0}, "17": {"effect": 0.03032582812011242, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iPJFYSP69A6WTARRMR3HU')
#   );
# </script>

# %%
# Print information on sample above
print(f"Force Plot for instance where True Value = {(selected_instances.iloc[3, 0]):.2f}, Predicted Value = {selected_instances.iloc[3, 1]:.2f}, and Residual = {selected_instances.iloc[3, 2]:.2f}")
# Out:
# Force Plot for instance where True Value = 17.82, Predicted Value = 39.69, and Residual = -21.87

# %%
# Define index being used
index = selected_instances.iloc[4].name

# Plot force plot
shap.plots.force(explainer.expected_value, 
                 shap_values[index], 
                 x_shap.iloc[index],
                text_rotation = 90)
# Out:
# <div id='i2X1C7D1K0DWBW2YTRPX4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 59.63934326171875, "outValue": 87.65743255615234, "link": "identity", "featureNames": ["Area-weighted average soil depth\n(QT)", "Mean Basin Elevation (QT)", "% of Soils with greater than 10%\nand less than 20% Clay (sqrt)", "Relief (QT)", "Area-weighted Average Soil\nPermeability (log)", "% of Soils with greater than 40%\nand less than 50% Clay (cbrt)", "% of Forests and Shrub Lands\n(NLCD 2011) (YJ)", "% of Cultivated Crop and Pasture\n(NLCD 2011) (sqrt)", "Max 24-Hour Precipitation for\n2-Year Return Period (QT)", "Mean Annual Precipitation (QT)", "Year", "Drainage Area (sq km) (QT)", "Peak Flow Region Number 1550", "Peak Flow Region Number 1551", "Peak Flow Region Number 1552", "Peak Flow Region Number 1553", "Peak Flow Region Number 1554", "Peak Flow Region Number 1555"], "features": {"0": {"effect": 7.038887977600098, "value": 0.2968312941748953}, "1": {"effect": 7.1605224609375, "value": -0.9111647383012761}, "2": {"effect": 0.553765058517456, "value": 0.0}, "3": {"effect": 1.9242414236068726, "value": -0.49065163896629843}, "4": {"effect": -0.42966070771217346, "value": -0.3281934702458043}, "5": {"effect": 0.48907747864723206, "value": 0.8523409348080596}, "6": {"effect": 2.287982702255249, "value": -0.05675842191207626}, "7": {"effect": 0.7564559578895569, "value": 0.042204753806523325}, "8": {"effect": 1.5049266815185547, "value": 0.3180288254732239}, "9": {"effect": 1.6426630020141602, "value": 0.19945930606174245}, "10": {"effect": 0.7408632040023804, "value": -0.5}, "11": {"effect": 1.7085376977920532, "value": 0.6432959191488015}, "12": {"effect": -0.0160888209939003, "value": 0.0}, "13": {"effect": 1.4960987567901611, "value": 1.0}, "14": {"effect": 0.25642016530036926, "value": 0.0}, "15": {"effect": 0.3331136107444763, "value": 0.0}, "16": {"effect": 0.5890711545944214, "value": 0.0}, "17": {"effect": -0.018788907676935196, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i2X1C7D1K0DWBW2YTRPX4')
#   );
# </script>

# %%
# Print information on sample above
print(f"Force Plot for instance where True Value = {(selected_instances.iloc[4, 0]):.2f}, Predicted Value = {selected_instances.iloc[4, 1]:.2f}, and Residual = {selected_instances.iloc[4, 2]:.2f}")
# Out:
# Force Plot for instance where True Value = 87.64, Predicted Value = 87.66, and Residual = -0.02

# %%
# Define index being used
index = selected_instances.iloc[5].name

# Plot force plot
shap.plots.force(explainer.expected_value, 
                 shap_values[index], 
                 x_shap.iloc[index],
                text_rotation = 90)
# Out:
# <div id='iB48QA2D0H2L9EES17JOR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 59.63934326171875, "outValue": 48.840049743652344, "link": "identity", "featureNames": ["Area-weighted average soil depth\n(QT)", "Mean Basin Elevation (QT)", "% of Soils with greater than 10%\nand less than 20% Clay (sqrt)", "Relief (QT)", "Area-weighted Average Soil\nPermeability (log)", "% of Soils with greater than 40%\nand less than 50% Clay (cbrt)", "% of Forests and Shrub Lands\n(NLCD 2011) (YJ)", "% of Cultivated Crop and Pasture\n(NLCD 2011) (sqrt)", "Max 24-Hour Precipitation for\n2-Year Return Period (QT)", "Mean Annual Precipitation (QT)", "Year", "Drainage Area (sq km) (QT)", "Peak Flow Region Number 1550", "Peak Flow Region Number 1551", "Peak Flow Region Number 1552", "Peak Flow Region Number 1553", "Peak Flow Region Number 1554", "Peak Flow Region Number 1555"], "features": {"0": {"effect": -5.338406085968018, "value": -0.43150923439413524}, "1": {"effect": -4.335294723510742, "value": 0.2690876329779828}, "2": {"effect": -0.7048559784889221, "value": 0.8814445764382484}, "3": {"effect": -0.5952104330062866, "value": 1.5198795232246676}, "4": {"effect": 0.04229661077260971, "value": 0.23389932557818954}, "5": {"effect": 0.010106531903147697, "value": 0.7491989618561646}, "6": {"effect": 1.504088044166565, "value": 0.3000763177524965}, "7": {"effect": 0.4183345437049866, "value": 0.011754010632106474}, "8": {"effect": -0.6689257621765137, "value": 0.9636810206807059}, "9": {"effect": -0.3344394862651825, "value": 1.064964857116357}, "10": {"effect": -1.4359264373779297, "value": 0.6}, "11": {"effect": 0.7577701210975647, "value": 1.2070359173974936}, "12": {"effect": -0.06588989496231079, "value": 0.0}, "13": {"effect": -0.5768225789070129, "value": 0.0}, "14": {"effect": 0.09202755987644196, "value": 0.0}, "15": {"effect": -0.10401666164398193, "value": 1.0}, "16": {"effect": 0.5587780475616455, "value": 0.0}, "17": {"effect": -0.022904060781002045, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iB48QA2D0H2L9EES17JOR')
#   );
# </script>

# %%
# Print information on sample above
print(f"Force Plot for instance where True Value = {(selected_instances.iloc[5, 0]):.2f}, Predicted Value = {selected_instances.iloc[5, 1]:.2f}, and Residual = {selected_instances.iloc[5, 2]:.2f}")
# Out:
# Force Plot for instance where True Value = 48.73, Predicted Value = 48.84, and Residual = -0.11

# %% [markdown]
# #### Decision Plots
# Decision Plots will show the same thing as force plots, but in a different format. This can be easier to visualize in some cases. The variables described above are the same.

# %%
# Define index being used
index = selected_instances.iloc[0].name

# Plot decision plot
shap.decision_plot(explainer.expected_value,
                   shap_values[index],
                   x_shap.iloc[index],
                  show = False)

# Save to results folder
shap_max_pos_1_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_decision_max_pos_1.png")
plt.savefig(shap_max_pos_1_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Print information on sample above
print(f"Decision Plot for instance where True Value = {(selected_instances.iloc[0, 0]):.2f}, Predicted Value = {selected_instances.iloc[0, 1]:.2f}, and Residual = {selected_instances.iloc[0, 2]:.2f}")
# Out:
# Decision Plot for instance where True Value = 60.73, Predicted Value = 36.30, and Residual = 24.43

# %%
# Define index being used
index = selected_instances.iloc[1].name

# Plot decision plot
shap.decision_plot(explainer.expected_value,
                   shap_values[index],
                   x_shap.iloc[index],
                  show = False)

# Save to results folder
shap_max_pos_2_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_decision_max_pos_2.png")
plt.savefig(shap_max_pos_2_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Print information on sample above
print(f"Decision Plot for instance where True Value = {(selected_instances.iloc[1, 0]):.2f}, Predicted Value = {selected_instances.iloc[1, 1]:.2f}, and Residual = {selected_instances.iloc[1, 2]:.2f}")
# Out:
# Decision Plot for instance where True Value = 93.45, Predicted Value = 73.59, and Residual = 19.87

# %%
# Define index being used
index = selected_instances.iloc[2].name

# Plot decision plot
shap.decision_plot(explainer.expected_value,
                   shap_values[index],
                   x_shap.iloc[index],
                  show = False)

# Save to results folder
shap_max_neg_1_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_decision_max_neg_1.png")
plt.savefig(shap_max_neg_1_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Print information on sample above
print(f"Decision Plot for instance where True Value = {(selected_instances.iloc[2, 0]):.2f}, Predicted Value = {selected_instances.iloc[2, 1]:.2f}, and Residual = {selected_instances.iloc[2, 2]:.2f}")
# Out:
# Decision Plot for instance where True Value = 27.36, Predicted Value = 57.83, and Residual = -30.46

# %%
# Define index being used
index = selected_instances.iloc[3].name

# Plot decision plot
shap.decision_plot(explainer.expected_value,
                   shap_values[index],
                   x_shap.iloc[index],
                  show = False)

# Save to results folder
shap_max_neg_2_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_decision_max_neg_2.png")
plt.savefig(shap_max_neg_2_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Print information on sample above
print(f"Decision Plot for instance where True Value = {(selected_instances.iloc[3, 0]):.2f}, Predicted Value = {selected_instances.iloc[3, 1]:.2f}, and Residual = {selected_instances.iloc[3, 2]:.2f}")
# Out:
# Decision Plot for instance where True Value = 17.82, Predicted Value = 39.69, and Residual = -21.87

# %%
# Define index being used
index = selected_instances.iloc[4].name

# Plot decision plot
shap.decision_plot(explainer.expected_value,
                   shap_values[index],
                   x_shap.iloc[index],
                  show = False)

# Save to results folder
shap_min_resid1_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_decision_min_resid1.png")
plt.savefig(shap_min_resid1_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Print information on sample above
print(f"Decision Plot for instance where True Value = {(selected_instances.iloc[4, 0]):.2f}, Predicted Value = {selected_instances.iloc[4, 1]:.2f}, and Residual = {selected_instances.iloc[4, 2]:.2f}")
# Out:
# Decision Plot for instance where True Value = 87.64, Predicted Value = 87.66, and Residual = -0.02

# %%
# Define index being used
index = selected_instances.iloc[5].name

# Plot decision plot
shap.decision_plot(explainer.expected_value,
                   shap_values[index],
                   x_shap.iloc[index],
                  show = False)

# Save to results folder
shap_min_resid2_path = os.path.join(BASE_DIR, "models", "model1_streamstats_va", "results", "figures", "shap_decision_min_resid2.png")
plt.savefig(shap_min_resid2_path, dpi = 300, bbox_inches = 'tight')

# Show plow
plt.show()

# %%
# Print information on sample above
print(f"Decision Plot for instance where True Value = {(selected_instances.iloc[5, 0]):.2f}, Predicted Value = {selected_instances.iloc[5, 1]:.2f}, and Residual = {selected_instances.iloc[5, 2]:.2f}")
# Out:
# Decision Plot for instance where True Value = 48.73, Predicted Value = 48.84, and Residual = -0.11

# %% [markdown]
# ### Step 4d. Geographic Results
# We'll plot the results from the testset in a couple ways.

# %%
# Read in coordinates from dbf file
dbf_path = os.path.join(BASE_DIR, 'data', 'GIS', 'vdeq_emd_snap_albers.dbf')
dbf = DBF(dbf_path)
coords = pd.DataFrame(iter(dbf))
coords = coords[['StationID',
               'LATITUDE_C',
               'LONGITUDE_']]

# print dataframe
coords
# Out:
#         StationID  LATITUDE_C  LONGITUDE_
# 0     1AACO006.10   38.728611  -77.203333
# 1     1AACO004.84   38.720500  -77.190722
# 2     1AACO009.14   38.761944  -77.207222
# 3     1ABRB002.15   39.046667  -77.432778
# 4     1ABRB015.38   38.959444  -77.544167
# ...           ...         ...         ...
# 1130  1BEBG002.31   38.797503  -78.522456
# 1131  1BLGC007.69   38.314806  -79.036281
# 1132  2-WER001.58   37.354772  -77.165433
# 1133  2-WPK002.93   37.325953  -77.726925
# 1134  4ATIP006.36   37.050611  -78.871194
#
# [1135 rows x 3 columns]

# %%
# Create dataframe for map plotting from test set
map_testset_df = pd.DataFrame(y_test)
map_testset_df['Prediction'] = xgb_pred
map_testset_df['Residual'] = xgb_residuals
map_testset_df['Residual_Abs'] = map_testset_df['Residual'].abs()

# Print dataframe
map_testset_df
# Out:
#       Mean Streambed Embeddedness (%)  Prediction   Residual  Residual_Abs
# 994                         27.636364   40.437912 -12.801548     12.801548
# 101                         29.454545   26.733158   2.721387      2.721387
# 486                         31.203704   30.756920   0.446784      0.446784
# 862                         90.000000   82.792809   7.207191      7.207191
# 1076                        80.545455   77.352081   3.193373      3.193373
# ...                               ...         ...        ...           ...
# 1081                        65.454545   62.344250   3.110296      3.110296
# 1085                        73.090909   69.660927   3.429982      3.429982
# 767                         92.181818   87.479332   4.702486      4.702486
# 184                         46.078431   49.421711  -3.343280      3.343280
# 351                         27.363636   57.826794 -30.463157     30.463157
#
# [224 rows x 4 columns]

# %%
# Read in vadeq_strmstats dataset to align index to StationID
vadeq_strmstats_path = os.path.join(BASE_DIR, "data", "processed", "virginia", "vadeq_strmsts_after_eda.xlsx")
vadeq_strmstats = pd.read_excel(vadeq_strmstats_path).drop(columns = 'Unnamed: 0')

# Display df
vadeq_strmstats
# Out:
#         StationID     Xembed  STATSGODEP     ELEV  STATSCLY20  RELIEF  \
# 0     1AACO006.10  62.545455       70.48   148.98        0.00   171.0
# 1     1AACO004.84  51.636364       66.65   308.44       51.85   451.0
# 2     1AACO006.10  56.818182       70.48   148.98        0.00   171.0
# 3     1AACO009.14  63.454545       66.39   324.56       54.64   357.0
# 4     1AAUA017.60  65.454545       56.77   317.16        0.30   278.0
# ...           ...        ...         ...      ...         ...     ...
# 1112  2BXRK001.64  67.090909       68.00   796.84        0.00   575.0
# 1113  2-JKS070.06  27.636364       44.64  2821.90       69.18  2550.0
# 1114  4ASNA007.82  95.909091       71.04   604.47        0.00   691.0
# 1115  8-MIC001.47  89.090909       72.00   298.12        0.00   197.0
# 1116  4ALRO010.18  77.818182       70.50   521.23        0.00   229.0
#
#       STATSPERM  STATSCLY50  LC11FORSHB  LC11CRPHAY  I24H2Y  PRECIP  Year  \
# 0         2.895        0.00       16.23        0.00   3.140  43.078  2006
# 1         2.395        0.00       22.49        0.11   3.167  43.888  2008
# 2         2.895        0.00       16.23        0.00   3.140  43.078  2008
# 3         2.271        0.00       22.65        0.09   3.169  43.981  2008
# 4         1.506        0.00       67.67        7.74   3.055  43.317  2005
# ...         ...         ...         ...         ...     ...     ...   ...
# 1112      2.000        0.00       95.34        0.00   3.723  49.307  2022
# 1113      5.089        0.00       77.43       17.98   2.959  43.163  2022
# 1114      1.114       90.49       60.89       23.17   3.319  45.609  2022
# 1115      1.000      100.00       41.15       49.07   3.290  43.671  2022
# 1116      1.086       88.37       64.48       22.69   3.307  45.533  2020
#
#       DRNAREA_SQKM  PKREGNO_1550  PKREGNO_1551  PKREGNO_1552  PKREGNO_1553  \
# 0         0.181817         False          True         False         False
# 1       104.894595          True         False         False         False
# 2         0.181817         False          True         False         False
# 3        94.016637         False          True         False         False
# 4        76.922703         False          True         False         False
# ...            ...           ...           ...           ...           ...
# 1112      1.968392         False         False         False          True
# 1113    269.358960         False         False         False         False
# 1114    206.940201         False          True         False         False
# 1115     14.633444         False          True         False         False
# 1116     21.937215         False         False          True         False
#
#       PKREGNO_1554  PKREGNO_1555
# 0            False         False
# 1            False         False
# 2            False         False
# 3            False         False
# 4            False         False
# ...            ...           ...
# 1112         False         False
# 1113          True         False
# 1114         False         False
# 1115         False         False
# 1116         False         False
#
# [1117 rows x 20 columns]

# %%
# Join testset results to original vadeq df
vadeq_testset = map_testset_df.merge(vadeq_strmstats,
                                     left_index = True,
                                     right_index = True,
                                     how = 'left')

# Display dataframe
vadeq_testset
# Out:
#       Mean Streambed Embeddedness (%)  Prediction   Residual  Residual_Abs  \
# 994                         27.636364   40.437912 -12.801548     12.801548
# 101                         29.454545   26.733158   2.721387      2.721387
# 486                         31.203704   30.756920   0.446784      0.446784
# 862                         90.000000   82.792809   7.207191      7.207191
# 1076                        80.545455   77.352081   3.193373      3.193373
# ...                               ...         ...        ...           ...
# 1081                        65.454545   62.344250   3.110296      3.110296
# 1085                        73.090909   69.660927   3.429982      3.429982
# 767                         92.181818   87.479332   4.702486      4.702486
# 184                         46.078431   49.421711  -3.343280      3.343280
# 351                         27.363636   57.826794 -30.463157     30.463157
#
#         StationID     Xembed  STATSGODEP     ELEV  STATSCLY20  RELIEF  ...  \
# 994   2-BLD012.56  27.636364       49.22  1816.75       25.53  2620.0  ...
# 101   2-DCK003.94  29.454545       37.47  2781.55      100.00  1790.0  ...
# 486   9-RDC051.21  31.203704       36.02  2851.60       99.99  1590.0  ...
# 862   4APDA000.35  90.000000       63.61   432.08        0.00   208.0  ...
# 1076  9-XFZ000.08  80.545455       57.88  2439.39        4.29   275.0  ...
# ...           ...        ...         ...      ...         ...     ...  ...
# 1081  1ACAM002.63  65.454545       68.15   261.39       35.00   491.0  ...
# 1085  3-KIL001.73  73.090909       59.00   772.11        0.00  1030.0  ...
# 767   5ATRE044.23  92.181818       63.40   244.74        0.00   186.0  ...
# 184   2-TYE008.77  46.078431       52.37  1562.62       41.23  3640.0  ...
# 351   5AKIT002.65  27.363636       63.00   485.57        0.00   145.0  ...
#
#       I24H2Y  PRECIP  Year  DRNAREA_SQKM  PKREGNO_1550  PKREGNO_1551  \
# 994    3.100  45.874  2019    212.379180         False         False
# 101    2.856  44.244  2011      5.231780         False         False
# 486    2.695  43.594  2007     18.725628         False         False
# 862    3.252  45.573  2018     12.846350         False          True
# 1076   2.979  40.505  2022      2.745389         False         False
# ...      ...     ...   ...           ...           ...           ...
# 1081   3.164  43.182  2022     93.239640          True         False
# 1085   3.382  45.583  2022      4.325283         False         False
# 767    3.353  45.882  2016     72.001722         False          True
# 184    3.603  51.230  2004    512.818020         False         False
# 351    3.270  45.264  2005      3.625986         False          True
#
#       PKREGNO_1552  PKREGNO_1553  PKREGNO_1554  PKREGNO_1555
# 994          False         False          True         False
# 101          False         False          True         False
# 486          False         False          True         False
# 862          False         False         False         False
# 1076         False          True         False         False
# ...            ...           ...           ...           ...
# 1081         False         False         False         False
# 1085         False          True         False         False
# 767          False         False         False         False
# 184          False          True         False         False
# 351          False         False         False         False
#
# [224 rows x 24 columns]

# %%
# Join coordinates with test set results
vadeq_testset_map = vadeq_testset.merge(coords,
                                       on = 'StationID',
                                       how = 'left')

# Display results of merging
vadeq_testset_map.describe()
# Out:
#        Mean Streambed Embeddedness (%)  Prediction    Residual  Residual_Abs  \
# count                       224.000000  224.000000  224.000000    224.000000
# mean                         59.211359   59.322388   -0.111029      5.743927
# std                          21.947992   17.670237    7.447161      4.725669
# min                           7.272727   17.425974  -30.463157      0.021023
# 25%                          44.272727   47.520121   -4.591133      2.597450
# 50%                          58.545455   59.773535   -0.148233      4.484927
# 75%                          76.379074   72.265312    4.115925      7.899068
# max                         100.000000   91.763870   24.427659     30.463157
#
#            Xembed  STATSGODEP         ELEV  STATSCLY20       RELIEF  \
# count  224.000000  224.000000   224.000000  224.000000   224.000000
# mean    59.211359   57.733170  1381.569643   26.910134  1187.907143
# std     21.947992    9.788615   951.161106   37.224361  1017.876834
# min      7.272727   36.000000    85.740000    0.000000    74.000000
# 25%     44.272727   50.510000   520.965000    0.000000   258.500000
# 50%     58.545455   59.000000  1173.525000    0.000000   838.500000
# 75%     76.379074   64.677500  2164.432500   44.225000  1815.000000
# max    100.000000   75.710000  4160.810000  100.000000  3750.000000
#
#         STATSPERM  STATSCLY50  LC11FORSHB  LC11CRPHAY      I24H2Y      PRECIP  \
# count  224.000000  224.000000  224.000000  224.000000  224.000000  224.000000
# mean     2.662924   20.001071   66.847634   18.403348    3.223786   46.202152
# std      1.889964   34.626591   21.606198   15.358642    0.389375    3.933111
# min      0.000000    0.000000    4.210000    0.000000    2.000000   37.826000
# 25%      1.245250    0.000000   53.815000    4.185000    2.996000   43.895000
# 50%      2.390500    0.000000   68.695000   17.270000    3.295500   45.469500
# 75%      3.011000   36.605000   83.567500   29.005000    3.427000   47.698250
# max     12.544000  100.000000  100.000000   81.200000    4.791000   67.680000
#
#               Year  DRNAREA_SQKM  LATITUDE_C  LONGITUDE_
# count   224.000000    224.000000  224.000000  224.000000
# mean   2013.071429    101.038782   37.470181  -79.374892
# std       5.461179    227.088302    0.673559    1.428454
# min    2004.000000      0.147111   36.568100  -83.131944
# 25%    2008.000000      4.765582   36.934140  -80.197367
# 50%    2013.000000     18.673828   37.333815  -79.152511
# 75%    2018.000000     73.490966   37.828050  -78.329034
# max    2022.000000   1647.233640   39.257833  -76.692292

# %%
# Create text column for map label
vadeq_testset_map['text'] = 'Station ID ' + vadeq_testset_map['StationID'] + ', ' + 'Actual: ' + vadeq_testset_map['Mean Streambed Embeddedness (%)'].astype(int).astype(str) + '%' + ', ' + 'Prediction: ' + vadeq_testset_map['Prediction'].astype(int).astype(str) + '%'

# Display new text column
vadeq_testset_map[['text']]
# Out:
#                                                   text
# 0    Station ID 2-BLD012.56, Actual: 27%, Predictio...
# 1    Station ID 2-DCK003.94, Actual: 29%, Predictio...
# 2    Station ID 9-RDC051.21, Actual: 31%, Predictio...
# 3    Station ID 4APDA000.35, Actual: 90%, Predictio...
# 4    Station ID 9-XFZ000.08, Actual: 80%, Predictio...
# ..                                                 ...
# 219  Station ID 1ACAM002.63, Actual: 65%, Predictio...
# 220  Station ID 3-KIL001.73, Actual: 73%, Predictio...
# 221  Station ID 5ATRE044.23, Actual: 92%, Predictio...
# 222  Station ID 2-TYE008.77, Actual: 46%, Predictio...
# 223  Station ID 5AKIT002.65, Actual: 27%, Predictio...
#
# [224 rows x 1 columns]

# %% [markdown]
# ##### Export geographic results dataset
# Location of map: https://arcg.is/1nXqzK1

# %%
# Export to csv
map_path = os.path.join(BASE_DIR, 'data', 'GIS', 'vadeq_map_testset.csv')
vadeq_testset_map.to_csv(map_path)

# %%
# Import dependencies again bc Dash is dramatic
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.graph_objects as go

# Create the Dash app
app = dash.Dash(__name__)

app.layout = html.Div([
    dcc.Graph(id='geo-scatter'),
    dcc.RangeSlider(
        id='year-slider',
        min=vadeq_testset_map['Year'].min(),
        max=vadeq_testset_map['Year'].max(),
        value=[vadeq_testset_map['Year'].min(), vadeq_testset_map['Year'].max()],
        marks={str(year): str(year) for year in vadeq_testset_map['Year'].unique()},
        step=None
    )
])

@app.callback(
    Output('geo-scatter', 'figure'),
    [Input('year-slider', 'value')]
)
def update_figure(selected_years):
    filtered_df = vadeq_testset_map[
        (vadeq_testset_map['Year'] >= selected_years[0]) &
        (vadeq_testset_map['Year'] <= selected_years[1])
    ]

    fig = go.Figure(data=go.Scattergeo(
        locationmode='USA-states',
        lon=filtered_df['LONGITUDE_'],
        lat=filtered_df['LATITUDE_C'],
        text=filtered_df['text'],
        mode='markers',
        marker=dict(
            size=8,
            opacity=0.8,
            reversescale=True,
            symbol='circle',
            line=dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            colorscale='spectral',
            cmin=filtered_df['Residual'].min(),
            color=filtered_df['Residual'],
            cmax=filtered_df['Residual'].max(),
            colorbar_title="Model Residuals<br>in % Embeddedness"
        )
    ))

    fig.update_geos(fitbounds='locations')
    fig.update_layout(
        title='Actual vs. Predicted Embeddedness<br>(Hover for Station ID)',
        geo=dict(
            scope='usa',
            showsubunits=True,
            projection_type='albers usa',
            showland=True,
            landcolor="rgb(250, 250, 250)",
            subunitcolor="Black",
            countrycolor="rgb(217, 217, 217)",
            countrywidth=0.5,
            subunitwidth=0.5
        ),
    )
    return fig

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Step 4e. Reference Site Comparison
# The VA DEQ was able to provide a categorical value for each site indicating its reference status. These were merged with the testset to analyze if clear clustering occurs.

# %%
# Import reference site datasets
upland_path = os.path.join(BASE_DIR, 'data', 'raw', 'virginia', 'GenusMMI_Raw_Uplands_Data.xlsx')
coast_path = os.path.join(BASE_DIR, 'data', 'raw', 'virginia', 'GenusMMI_Raw_Coast_Data.xlsx')
upland_ref = pd.read_excel(upland_path)
coast_ref = pd.read_excel(coast_path)

# Select for only reference status (this is all we need for plotting right now)
upland_ref = upland_ref[['StationID', 'RefStress']]
coast_ref = coast_ref[['StationID', 'RefStress']]

# %%
# Select for only unique pairs (hopefully this works first try)
unique_upland_ref = upland_ref.drop_duplicates(subset=['StationID', 'RefStress'])
unique_coast_ref = coast_ref.drop_duplicates(subset = ['StationID', 'RefStress'])

# %%
# Display statistics of upland reference
unique_upland_ref.describe()
# Out:
#           StationID RefStress
# count          1606       953
# unique         1606         3
# top     3-RAP088.21       Int
# freq              1       380

# %%
# Display statistics of coast reference
unique_coast_ref.describe()
# Out:
#           StationID RefStress
# count           223       130
# unique          223         3
# top     8-MAR008.23       Ref
# freq              1        65

# %%
# Join reference site information to the original dataset
join1 = vadeq_testset.merge(unique_upland_ref,
                           on = 'StationID',
                           how = "left")
join1[['RefStress']].describe()
# Out:
#        RefStress
# count        117
# unique         3
# top          Ref
# freq          46

# %%
# Join reference site information to the original dataset
join2 = vadeq_testset.merge(unique_coast_ref,
                                on = 'StationID',
                               how = "left")
join2[['RefStress']].describe()
# Out:
#        RefStress
# count          4
# unique         3
# top          Int
# freq           2

# %%
# Concatenate two datasets into full testset dataset
vadeq_testset_refs = pd.concat([join1, join2])
vadeq_testset_refs[['RefStress']].describe()
# Out:
#        RefStress
# count        121
# unique         3
# top          Ref
# freq          47

# %%
# Create same scatterplot of residuals with categorical color-coding based on reference site information
plt.figure(figsize=(10, 6))
sns.scatterplot(data=vadeq_testset_refs, x ='Prediction', 
                y = 'Residual', 
                hue='RefStress', 
                palette = {'Str': 'r', 'Int': 'orange', 'Ref': 'g'})

# Set plot limits, labels, and other details
plt.ylim(-100, 100)
plt.xlabel('Predicted Embeddedness Values (%)')
plt.ylabel('Residuals')
plt.title('XGBoost VA Model Residual Plot')
plt.axhline(y=0, color='black', linestyle='--')
plt.legend(title='Reference Site Category')

# Save plot
ref_plt_path = os.path.join(BASE_DIR, 'models', 'model1_streamstats_va', 'results', 'figures', 'ref_vadeq_residuals.png')
plt.savefig(ref_plt_path, dpi = 300)

# Show plot
plt.show()
